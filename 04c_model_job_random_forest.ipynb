# %%
#constants

DATA_PATH = 'C:\\Users\\gt\\End to End Data Science Project\\Processed data\\cleaned_data.pkl'

ROLE_COLS = ['DevType']
TECH_COLS = ['LanguageHaveWorkedWith',
             'DatabaseHaveWorkedWith',
             'PlatformHaveWorkedWith',
             'WebframeHaveWorkedWith', 
             'MiscTechHaveWorkedWith', 
             'ToolsTechHaveWorkedWith', 
             'NEWCollabToolsHaveWorkedWith']

MLFLOW_TRACKING_URI = 'C:\\Users\\gt\\End to End Data Science Project\\models\\mlruns'
MLFLOW_EXPERIMENT_NAME = "skills_jobs_Stackoverflow"

LOG_PATH = "C:\\Users\\gt\\End to End Data Science Project\\models\\temp\\"
LOG_DATA_PKL    =  "data.pkl"
LOG_MODEL_PKL   =  "model.pkl"
LOG_METRICS_PKL =  "metrics.pkl"

# %%
# Load packages
import pandas as pd 
import numpy as np
import logging
import pickle
import random
import plotly 
import os
from pathlib import Path

import mlflow
from mlflow.tracking import MlflowClient

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline, FeatureUnion
from sklearn.feature_selection import VarianceThreshold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import auc, accuracy_score, confusion_matrix, f1_score, precision_score, recall_score

from sklearn.decomposition import PCA, KernelPCA

from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from matplotlib import pyplot as plt

# %% [markdown]
# _________

# %% [markdown]
# ### Functions

# %%
def calculate_quality(ground_truth, predictions, metric_function, sort_values=False):
    quality_scores = {}
    for col in predictions.columns:
        role_pred  = predictions[col].copy()
        role_truth = ground_truth[col].copy()
        quality_scores[col] = round(metric_function(role_truth, role_pred) * 100, 2)
        
    quality_scores = pd.Series(quality_scores.values(), index=quality_scores.keys())
    if sort_values:
        quality_scores = quality_scores.sort_values()
    
    return quality_scores

# %% [markdown]
# -------------

# %% [markdown]
# ## Prep data

# %%
# Read Data
df = pd.read_pickle(DATA_PATH)

# %% [markdown]
# ### Balance classes

# %%
# Check the total samples of roles
roles_df = df["DevType"].copy()
roles_df.sum(axis=0)
# Out:
# Academic researcher                               1708
# Data or business analyst                          1658
# Data scientist or machine learning specialist     2460
# Database administrator                            1210
# DevOps specialist                                 3056
# Developer, QA or test                             1135
# Developer, back-end                              17084
# Developer, desktop or enterprise applications     4845
# Developer, embedded applications or devices       2138
# Developer, front-end                              8932
# Developer, full-stack                            20655
# Developer, game or graphics                        899
# Developer, mobile                                 4751
# Engineer, data                                    1941
# Scientist                                         1046
# System administrator                              2069
# dtype: int64

# %%
# Resample roles
samples_per_class = 1200
resampled_roles = []

for role_col in roles_df.columns:
    sub_df = roles_df.loc[roles_df[role_col] == 1].copy()

    if len(sub_df) < samples_per_class:
        # Upsample
        sub_df = sub_df.sample(samples_per_class, replace=True, random_state=0)
    else:
        # Downsample
        sub_df = sub_df.sample(samples_per_class, random_state=0)

    resampled_roles.append(sub_df)

# %%
# Construct dfs
roles_df = pd.concat(resampled_roles)
df = df.loc[roles_df.index].copy()

# %%
roles_df.sum(axis=0)
# Out:
# Academic researcher                              2280
# Data or business analyst                         1965
# Data scientist or machine learning specialist    2576
# Database administrator                           1765
# DevOps specialist                                2170
# Developer, QA or test                            1514
# Developer, back-end                              5710
# Developer, desktop or enterprise applications    2690
# Developer, embedded applications or devices      1773
# Developer, front-end                             2614
# Developer, full-stack                            5602
# Developer, game or graphics                      1441
# Developer, mobile                                2155
# Engineer, data                                   2046
# Scientist                                        1910
# System administrator                             2110
# dtype: int64

# %% [markdown]
# ## Split to train and test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop('DevType', axis=1),
                                                    df['DevType'],
                                                    random_state=0)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %% [markdown]
# _________

# %% [markdown]
# # Train models

# %% [markdown]
# ### Initialize MLflow

# %%
# Initialize client and experiment
client = MlflowClient() 
mlflow.set_experiment(MLFLOW_EXPERIMENT_NAME)
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# %% [markdown]
# ### 1. Random Forest

# %% [markdown]
# we will use **Random Forest** becaues the data contains many features and most of them are sparse and jobs will not use all of the features.
#
# Feaures are correlated so, we will use **PCA**
#
# by using **Robust Scaler** we can remove the outliers where It scales features using statistics that are robust to outliers. This method removes the median and scales the data in the range between 1st quartile and 3rd quartile. i.e., in between 25th quantile and 75th quantile range. This range is also called an Interquartile range.

# %%
rf_clf = make_pipeline(RobustScaler(),
                       PCA(n_components=0.95),
                       RandomForestClassifier(n_jobs=8,
                                              verbose=1,
                                              random_state=0))

rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    7.1s finished
# Pipeline(steps=[('robustscaler', RobustScaler()),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(n_jobs=8, random_state=0, verbose=1))])

# %%
# Evaluate on train set
predictions =  pd.DataFrame(rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores = pd.concat(train_scores,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    1.4s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores = pd.concat(test_scores,axis=1)
mean_test_scores = test_scores.mean()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    0.7s finished

# %%
print(test_scores.mean())
test_scores.sort_values("precision_score")
# Out:
# accuracy_score     92.618750
# precision_score    93.843750
# recall_score       49.734375
# f1_score           63.865000
# dtype: float64
#                                                accuracy_score  \
# Developer, full-stack                                   84.08
# Developer, back-end                                     79.08
# Developer, front-end                                    89.67
# Data scientist or machine learning specialist           93.73
# Developer, desktop or enterprise applications           90.83
# Academic researcher                                     94.94
# Scientist                                               97.10
# Developer, mobile                                       93.92
# Data or business analyst                                94.48
# Developer, embedded applications or devices             94.50
# DevOps specialist                                       92.73
# Developer, game or graphics                             98.02
# Database administrator                                  94.96
# Engineer, data                                          93.90
# System administrator                                    93.42
# Developer, QA or test                                   96.54
#
#                                                precision_score  recall_score  \
# Developer, full-stack                                    78.82         62.02
# Developer, back-end                                      84.29         36.98
# Developer, front-end                                     88.24         32.56
# Data scientist or machine learning specialist            88.30         61.73
# Developer, desktop or enterprise applications            92.83         34.21
# Academic researcher                                      93.11         60.79
# Scientist                                                95.41         75.56
# Developer, mobile                                        95.49         47.57
# Data or business analyst                                 96.28         47.65
# Developer, embedded applications or devices              96.34         37.98
# DevOps specialist                                        97.44         35.58
# Developer, game or graphics                              98.23         75.48
# Database administrator                                   98.54         45.93
# Engineer, data                                           99.06         42.03
# System administrator                                     99.55         41.45
# Developer, QA or test                                    99.57         58.23
#
#                                                f1_score
# Developer, full-stack                             69.42
# Developer, back-end                               51.40
# Developer, front-end                              47.57
# Data scientist or machine learning specialist     72.66
# Developer, desktop or enterprise applications     50.00
# Academic researcher                               73.56
# Scientist                                         84.33
# Developer, mobile                                 63.50
# Data or business analyst                          63.75
# Developer, embedded applications or devices       54.48
# DevOps specialist                                 52.13
# Developer, game or graphics                       85.36
# Database administrator                            62.65
# Engineer, data                                    59.02
# System administrator                              58.53
# Developer, QA or test                             73.48

# %% [markdown]
# The precision_score is far better than the results we got using logistics regression

# %% [markdown]
# ### Log

# %%
## Log
# Data details
data_details = {"data_path": DATA_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices": X_test.index.tolist(),
                "features_names": X_train.columns.droplevel(0).tolist(),
                "targets_names": Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA - Basic",
         "model_details": str(rf_clf),
         "model_object": rf_clf}

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Performance details
classes_metrics = {"train_scores": train_scores,
                   "test_scores": test_scores}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track
with mlflow.start_run(experiment_id=exp.experiment_id,
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)

    # Track metrics
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)

# %%
exp = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
# Get all runs 
runs = mlflow.search_runs([exp.experiment_id])
runs
# Out:
#                              run_id experiment_id    status  \
# 0  ae19f7e29828489f9f3391a099c90ce3             2  FINISHED
# 1  c8d5f7fe46b3470fb45065151362c7c0             2  FINISHED
# 2  f3d9e81224a546dc9f0779f8d3b77497             2  FINISHED
# 3  2d620efffdac4b9db4adad274b4a7ff9             2  FINISHED
# 4  bb29a0874d724f42b4b0ee1ffbb25f01             2  FINISHED
#
#                                         artifact_uri  \
# 0  file:///C:/Users/gt/End%20to%20End%20Data%20Sc...
# 1  file:///C:/Users/gt/End%20to%20End%20Data%20Sc...
# 2  file:///C:/Users/gt/End%20to%20End%20Data%20Sc...
# 3  file:///C:/Users/gt/End%20to%20End%20Data%20Sc...
# 4  file:///C:/Users/gt/End%20to%20End%20Data%20Sc...
#
#                         start_time                         end_time  \
# 0 2022-07-30 11:36:17.867000+00:00 2022-07-30 11:36:23.354000+00:00
# 1 2022-07-30 07:36:32.519000+00:00 2022-07-30 07:37:17.664000+00:00
# 2 2022-07-30 07:27:38.411000+00:00 2022-07-30 07:28:38.186000+00:00
# 3 2022-07-30 06:50:44.689000+00:00 2022-07-30 06:50:46.438000+00:00
# 4 2022-07-30 06:49:49.326000+00:00 2022-07-30 06:49:49.447000+00:00
#
#    metrics.recall_score  metrics.accuracy_score  metrics.precision_score  \
# 0             49.734375               92.618750                93.843750
# 1             49.005000               92.561250                94.486875
# 2             49.005000               92.561250                94.486875
# 3             49.005000               92.561250                94.486875
# 4             29.890000               88.939375                62.420625
#
#    metrics.f1_score                            tags.mlflow.source.name  \
# 0         63.865000  D:\Anaconda\lib\site-packages\ipykernel_launch...
# 1         63.487500  D:\Anaconda\lib\site-packages\ipykernel_launch...
# 2         63.487500  D:\Anaconda\lib\site-packages\ipykernel_launch...
# 3         63.487500  D:\Anaconda\lib\site-packages\ipykernel_launch...
# 4         38.613125  D:\Anaconda\lib\site-packages\ipykernel_launch...
#
#   tags.mlflow.source.type                             tags.mlflow.runName  \
# 0                   LOCAL                 Random Forest: with PCA - Basic
# 1                   LOCAL  Random Forest: with PCA + Hyperparamter tuning
# 2                   LOCAL  Random Forest: with PCA + Hyperparamter tuning
# 3                   LOCAL                 Random Forest: with PCA - Basic
# 4                   LOCAL            Baseline model: Logistic Regression
#
#   tags.mlflow.user
# 0               gt
# 1               gt
# 2               gt
# 3               gt
# 4               gt

# %% [markdown]
# ______________

# %% [markdown]
# ### 2. Hyper parameter tuning

# %% [markdown]
# **Parameters** are the variables that are used by the Machine Learning algorithm for predicting the results based on the input historic data. These are estimated by using an optimization algorithm by the Machine Learning algorithm itself. Thus, these variables are not set or hardcoded by the user or professional. These variables are served as a part of model training. Example of Parameters: Coefficient of independent variables Linear Regression and Logistic Regression.

# %% [markdown]
# **Hyperparameters** are the variables that the user specify usually while building the Machine Learning model. thus, hyperparameters are specified before specifying the parameters or we can say that hyperparameters are used to evaluate optimal parameters of the model. the best part about hyperparameters is that their values are decided by the user who is building the model. For example, max_depth in Random Forest Algorithms, k in KNN Classifier.

# %%
hpt_rf_clf = make_pipeline(RobustScaler(),
                           PCA(),
                           RandomForestClassifier(n_jobs=8,
                                                  verbose=1,
                                                  random_state=0))

# %%
# list(hpt_rf_clf.get_params().keys())
#n_estimators : This is the number of trees you want to build before taking the maximum voting or averages of predictions. 
#Using the max_depth parameter, I can limit up to what depth I want every tree in my random forest to grow.
#when max_depth is None that means that each tree will expand until every leaf is pure. 
#A pure leaf is one where all of the data on the leaf comes from the same class.

tuned_parameters = [{
    'pca__n_components': [0.7, 0.85, 0.95],
    'randomforestclassifier__n_estimators': [250, 500],
    'randomforestclassifier__max_depth':    [3, 10, None],
}]

# %%
# our goal should be to find the best hyperparameters values to get the perfect prediction results from our model.
hpt_rf_clf = GridSearchCV(hpt_rf_clf, tuned_parameters)
hpt_rf_clf.fit(X_train.values, Y_train.values)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    3.2s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    3.1s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    6.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    6.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   12.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   14.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   12.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   13.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   13.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   24.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   21.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   26.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   22.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   21.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    3.5s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    3.5s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    3.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    9.4s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    8.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   17.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   19.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   17.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   16.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   17.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   13.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   14.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   14.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   14.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   14.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   29.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   33.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    4.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   30.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   29.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   30.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 235 out of 250 | elapsed:    4.6s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    7.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    5.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    4.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   10.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    8.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    9.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done 352 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    9.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   10.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    1.0s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   11.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   21.7s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   22.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   18.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   21.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   23.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   21.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.5s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   17.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   12.9s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   17.6s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   17.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   17.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.7s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:   19.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 250 out of 250 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   36.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   36.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   41.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    2.1s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   35.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.6s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   33.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   38.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.4s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   37.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.9s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:   23.0s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:   26.5s finished
# GridSearchCV(estimator=Pipeline(steps=[('robustscaler', RobustScaler()),
#                                        ('pca', PCA()),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(n_jobs=8,
#                                                                random_state=0,
#                                                                verbose=1))]),
#              param_grid=[{'pca__n_components': [0.7, 0.85, 0.95],
#                           'randomforestclassifier__max_depth': [3, 10, None],
#                           'randomforestclassifier__n_estimators': [250, 500]}])

# %%
hpt_rf_clf.best_params_
# Out:
# {'pca__n_components': 0.7,
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__n_estimators': 500}

# %% [markdown]
# 0.7 is the best in pca so, we can decrease it to 0.6 for example a also we can put n_estimators values more than 500 and we will see if the model gets better results

# %%
# Evaluate on training set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_train.values),
                            columns=Y_train.columns)
train_scores_ = {score.__name__: calculate_quality(Y_train, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
train_scores_ = pd.concat(train_scores_,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    7.6s finished

# %%
# Evaluate on test set
predictions =  pd.DataFrame(hpt_rf_clf.predict(X_test.values),
                            columns=Y_test.columns)
test_scores_ = {score.__name__: calculate_quality(Y_test, predictions, score) 
                for score in [accuracy_score, precision_score, recall_score, f1_score]}
test_scores_ = pd.concat(test_scores_,axis=1)
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    3.7s finished

# %%
print(test_scores_.mean())
test_scores
# Out:
# accuracy_score     92.699375
# precision_score    92.368750
# recall_score       51.480000
# f1_score           65.147500
# dtype: float64
#                                                accuracy_score  \
# Academic researcher                                     94.38
# Data or business analyst                                94.62
# Data scientist or machine learning specialist           93.94
# Database administrator                                  95.00
# DevOps specialist                                       92.90
# Developer, QA or test                                   96.54
# Developer, back-end                                     79.25
# Developer, desktop or enterprise applications           90.85
# Developer, embedded applications or devices             94.62
# Developer, front-end                                    89.92
# Developer, full-stack                                   83.90
# Developer, game or graphics                             97.90
# Developer, mobile                                       94.85
# Engineer, data                                          93.94
# Scientist                                               97.06
# System administrator                                    93.52
#
#                                                precision_score  recall_score  \
# Academic researcher                                      89.94         57.91
# Data or business analyst                                 95.29         49.69
# Data scientist or machine learning specialist            89.40         62.50
# Database administrator                                   99.03         46.15
# DevOps specialist                                        92.89         39.14
# Developer, QA or test                                    99.57         58.23
# Developer, back-end                                      79.57         41.23
# Developer, desktop or enterprise applications            92.50         34.53
# Developer, embedded applications or devices              94.38         40.38
# Developer, front-end                                     85.57         36.03
# Developer, full-stack                                    75.98         65.38
# Developer, game or graphics                              99.26         73.02
# Developer, mobile                                        90.88         59.74
# Engineer, data                                           97.74         43.03
# Scientist                                                96.34         74.34
# System administrator                                     99.56         42.38
#
#                                                f1_score
# Academic researcher                               70.46
# Data or business analyst                          65.32
# Data scientist or machine learning specialist     73.57
# Database administrator                            62.96
# DevOps specialist                                 55.07
# Developer, QA or test                             73.48
# Developer, back-end                               54.31
# Developer, desktop or enterprise applications     50.28
# Developer, embedded applications or devices       56.57
# Developer, front-end                              50.71
# Developer, full-stack                             70.28
# Developer, game or graphics                       84.14
# Developer, mobile                                 72.09
# Engineer, data                                    59.75
# Scientist                                         83.92
# System administrator                              59.45

# %% [markdown]
# it seems that the results didn't change alot which means the model is stable

# %% [markdown]
# ## Log

# %%
# Data details
data_details = {"data_path": DATA_PATH,
                "training_indices": X_train.index.tolist(),
                "test_indices":     X_test.index.tolist(), 
                "features_names":   X_train.columns.droplevel(0).tolist(),
                "targets_names":    Y_train.columns.tolist()}

with open(os.path.join(LOG_PATH, LOG_DATA_PKL), "wb") as output_file:
    pickle.dump(data_details, output_file)

# %%
# Model
model = {"model_description": "Random Forest: with PCA + Hyperparamter tuning",
         "model_details": str(hpt_rf_clf),
         "model_object": hpt_rf_clf} 

with open(os.path.join(LOG_PATH, LOG_MODEL_PKL), "wb") as output_file:
    pickle.dump(model, output_file)

# %%
# Preformance details
classes_metrics = {"train_scores": train_scores_, 
                   "test_scores":  test_scores_}

with open(os.path.join(LOG_PATH, LOG_METRICS_PKL), "wb") as output_file:
    pickle.dump(classes_metrics, output_file)

# %%
# Start a new run and track 
with mlflow.start_run(experiment_id=exp.experiment_id, 
                      run_name=model["model_description"]):
    # Log pickles
    mlflow.log_artifacts(LOG_PATH)  
    
    # Track metrics 
    for metric, score in mean_test_scores.items():
        mlflow.log_metric(metric, score)
